# %% [markdown]
# <a href="https://colab.research.google.com/github/seongwoojang1123/Effusion-OSA-TMD/blob/main/1_data_preprocessing_Effusion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

file_path = '/content/drive/MyDrive/Effusion OSA TMD/20250831_Effusion_TMD_Pain_Data.xlsx'

df = pd.read_excel(file_path, sheet_name='20250830_20250829_20250226_2024')

df.replace("", np.nan, inplace=True)

columns = df.columns
print(len(columns))
print(columns)
df.head()
# Out:
# 21
# Index(['No', 'Effusion', 'Effusion grade', 'Sex (Female)', 'Age', 'ADD', 'OA',
#        'VAS', 'DI', 'PI', 'CMI', 'Symptom duration', 'TMJ noise', 'Locking',
#        'Muscle stiffness', 'Tinnitus', 'Bruxism', 'Effusion_123',
#        'Affected side_123', 'ADD_123', 'OA_123'],
#       dtype='object')
#    No  Effusion  Effusion grade  Sex (Female)  Age  ADD  OA  VAS        DI  \
# 0   1         0               0             2   46    1   1    1  0.166667
# 1   2         0               0             1   15    1   1    2  0.083333
# 2   3         0               0             1   16    1   0    2  0.166667
# 3   4         0               0             2   50    0   0    2  0.000000
# 4   5         0               0             2   44    1   1    3  0.434524
#
#          PI  ...  Symptom duration  TMJ noise  Locking  Muscle stiffness  \
# 0  0.000000  ...              0.00          1        1                 0
# ...

# %%
df.describe()
# Out:
#                No    Effusion  Effusion grade  Sex (Female)         Age  \
# count  221.000000  221.000000      221.000000    221.000000  221.000000
# mean   111.000000    0.696833        0.986425      1.669683   36.027149
# std     63.941379    0.460670        0.771537      0.471395   17.962314
# min      1.000000    0.000000        0.000000      1.000000   11.000000
# 25%     56.000000    0.000000        0.000000      1.000000   20.000000
# 50%    111.000000    1.000000        1.000000      2.000000   35.000000
# 75%    166.000000    1.000000        2.000000      2.000000   49.000000
# max    221.000000    1.000000        2.000000      2.000000   83.000000
#
#               ADD          OA         VAS          DI          PI  ...  \
# count  221.000000  221.000000  221.000000  221.000000  221.000000  ...
# mean     0.733032    0.710407    4.588235    0.266699    0.213963  ...
# std      0.443380    0.454603    2.265883    0.238480    0.296509  ...
# ...
